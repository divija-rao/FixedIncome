# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.optimize import minimize
from tqdm import tqdm

# %%
# Load and prepare the data (same as before)
df = pd.read_csv('/Users/dr/Documents/GitHub/FixedIncome/STRIPS_data.csv')
latest_date = "2025-02-04"
latest_data = df[df['Date'] == latest_date].iloc[0]

# Extract times, prices, and yields
maturities = []
prices = []
yields = []

for i in range(46):
    maturity_label = df.columns[1 + i*3].split('_')[1]
    time_col = f'Time_{maturity_label}'
    price_col = f'Price_{maturity_label}'
    yield_col = f'Yield_{maturity_label}'
    
    time = latest_data[time_col]
    price = latest_data[price_col]
    yield_val = latest_data[yield_col]
    
    maturities.append(time)
    prices.append(price)
    yields.append(yield_val)

# Convert to numpy arrays
maturities = np.array(maturities)
prices = np.array(prices)
yields = np.array(yields)

# Filter out very short maturities
min_maturity = 0.1
mask = maturities >= min_maturity
filtered_maturities = maturities[mask]
filtered_prices = prices[mask]
filtered_yields = yields[mask]

# %%
class BGMMonteCarlo:
    def __init__(self, times, initial_forwards, volatilities, corr_matrix=None):
        self.times = np.array(times)
        self.initial_forwards = np.array(initial_forwards)
        self.volatilities = np.array(volatilities)
        self.N = len(times) - 1
        self.deltas = np.diff(times)
        
        if corr_matrix is None:
            self.corr_matrix = np.eye(self.N)
        else:
            self.corr_matrix = corr_matrix
        
        # Perform Cholesky decomposition for correlated random numbers
        try:
            self.cholesky = np.linalg.cholesky(self.corr_matrix)
        except np.linalg.LinAlgError:
            # If matrix isn't positive definite, use nearest correlation matrix
            self.corr_matrix = self._nearest_correlation_matrix(self.corr_matrix)
            self.cholesky = np.linalg.cholesky(self.corr_matrix)
    
    def _nearest_correlation_matrix(self, corr_matrix):
        """Helper function to ensure positive definite correlation matrix"""
        # Simple approach - add small diagonal adjustment
        n = corr_matrix.shape[0]
        adj = np.eye(n) * 1e-6
        return corr_matrix + adj
    
    def simulate_forward_rates(self, num_simulations, num_steps, dt):
        """Simulate forward rate paths using Monte Carlo"""
        paths = np.zeros((num_simulations, num_steps + 1, self.N))
        paths[:, 0, :] = self.initial_forwards
        
        for t in tqdm(range(1, num_steps + 1), desc="Simulating paths"):
            # Generate correlated random numbers
            z = norm.rvs(size=(num_simulations, self.N))
            correlated_z = np.dot(z, self.cholesky.T)
            
            # Euler discretization of BGM dynamics
            drift = self.calculate_drift(paths[:, t-1, :])
            diffusion = paths[:, t-1, :] * self.volatilities * np.sqrt(dt)
            
            paths[:, t, :] = paths[:, t-1, :] * np.exp(
                (drift - 0.5 * self.volatilities**2) * dt 
                + diffusion * correlated_z
            )
        
        return paths
    
    def calculate_drift(self, current_forwards):
        """Calculate the drift term in the BGM dynamics"""
        drift = np.zeros_like(current_forwards)
        for i in range(self.N):
            for j in range(i + 1):
                rho_ij = self.corr_matrix[i, j]
                term = (self.deltas[j] * current_forwards[:, j] * self.volatilities[i] * 
                       self.volatilities[j] * rho_ij) / (
                           1 + self.deltas[j] * current_forwards[:, j])
                drift[:, i] += term
        return drift
    
    def zero_coupon_bond(self, T, paths, dt):
        """Calculate zero coupon bond price for maturity T"""
        step = min(int(T / dt), paths.shape[1] - 1)
        
        # Calculate discount factor for each path
        discount_factors = np.ones(paths.shape[0])
        for i in range(step + 1):
            t = i * dt
            if t > T:
                break
            discount_factors /= (1 + self.deltas[0] * paths[:, i, 0])  # Simplified
        
        return np.mean(discount_factors) * 100
    
    def price_coupon_bond(self, coupon_rate, maturity, frequency, paths, dt):
        """Price a coupon-bearing bond using simulated paths"""
        coupon = 100 * coupon_rate / frequency
        periods = int(maturity * frequency)
        price = 0
        
        for i in range(1, periods + 1):
            t = i / frequency
            if t > maturity:
                break
            price += coupon * self.zero_coupon_bond(t, paths, dt)
        
        # Add principal payment at maturity
        price += 100 * self.zero_coupon_bond(maturity, paths, dt)
        
        return price / 100  # Normalized price

# %%
def calibrate_with_monte_carlo(times, yields, prices, num_simulations=500, num_steps=50):
    """Calibrate BGM parameters using Monte Carlo simulation"""
    # Calculate initial forwards from prices
    initial_forwards = np.diff(-np.log(prices[:-1]/100)) / np.diff(times[:-1])
    
    # Ensure we have matching dimensions
    n_forwards = len(times) - 1
    if len(initial_forwards) > n_forwards:
        initial_forwards = initial_forwards[:n_forwards]
    elif len(initial_forwards) < n_forwards:
        initial_forwards = np.pad(initial_forwards, (0, n_forwards - len(initial_forwards)), 
                                 'constant', constant_values=initial_forwards[-1])
    
    volatilities = np.full(n_forwards, 0.2)
    
    # Simple correlation matrix
    corr_matrix = np.exp(-0.1 * np.abs(np.subtract.outer(times[:-1], times[:-1])))
    
    # Monte Carlo parameters
    dt = times[-1] / num_steps
    
    # Objective function to minimize
    def objective(params):
        # Split params into forwards and volatilities
        forwards = params[:n_forwards]
        vols = params[n_forwards:]
        
        bgm = BGMMonteCarlo(times, forwards, vols, corr_matrix)
        paths = bgm.simulate_forward_rates(num_simulations, num_steps, dt)
        
        # Calculate model yields for maturities
        model_prices = []
        for t in times[1:]:
            zcb_price = bgm.zero_coupon_bond(t, paths, dt)
            model_prices.append(zcb_price)
        
        # Convert to yields
        model_yields = -np.log(np.array(model_prices)/100) / times[1:] * 100
        
        # Calculate MSE against market yields
        mse = np.mean((model_yields - yields[1:]*100)**2)
        return mse
    
    # Bounds for parameters
    bounds = [(0.0001, 0.2) for _ in range(n_forwards)]  # forwards
    bounds += [(0.01, 0.5) for _ in range(n_forwards)]   # volatilities
    
    # Initial parameter vector
    x0 = np.concatenate([initial_forwards, volatilities])
    
    # Optimization
    result = minimize(objective, x0, bounds=bounds, method='L-BFGS-B', 
                      options={'maxiter': 10, 'disp': True})
    
    # Split optimized parameters
    opt_forwards = result.x[:n_forwards]
    opt_vols = result.x[n_forwards:]
    
    return opt_forwards, opt_vols, corr_matrix

# %%
# Calibrate the model using Monte Carlo
print("Calibrating BGM model with Monte Carlo...")
opt_forwards, opt_vols, corr_matrix = calibrate_with_monte_carlo(
    filtered_maturities, filtered_yields, filtered_prices, 
    num_simulations=200, num_steps=30
)
# Out:
# Calibrating BGM model with Monte Carlo...
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 84.27it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.27it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 118.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.30it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.85it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 85.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 124.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 117.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.72it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 103.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 106.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.85it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 87.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.30it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.30it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 124.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.72it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 87.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.50it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.98it/s]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           88     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.68446D+00    |proj g|=  3.00000D-01
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.76it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 124.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 93.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.02it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.97it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.97it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 82.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.76it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.76it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 87.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.85it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.78it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 81.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 124.85it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.59it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 118.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 95.59it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.39it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.53it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 116.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 93.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.50it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.39it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.28it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.31it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.12it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.84it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.39it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 123.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 92.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.39it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 89.53it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.53it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 82.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.50it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.80it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.02it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.82it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 85.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.84it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 87.30it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.50it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.31it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.12it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.28it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 121.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 96.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.81it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.12it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 82.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.82it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 76.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.12it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 115.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 123.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 121.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 112.50it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 124.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 120.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 121.80it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 87.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 80.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.81it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.80it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 83.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.27it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.97it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 81.27it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.97it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.28it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 75.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.76it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 117.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 75.97it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 110.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 118.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 109.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 115.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.30it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.31it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 85.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.81it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.80it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 107.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.53it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.53it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.12it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 93.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.80it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.81it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.68it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 129.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 89.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.30it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.97it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.78it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.12it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 87.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.81it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.85it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.02it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.54it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.82it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 110.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.78it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.28it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.33it/s]
# ...
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 121.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 94.80it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.84it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.09it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.48it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.43it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.07it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.50it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.66it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.94it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.31it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.51it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.46it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 119.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 81.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 127.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.89it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.67it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.02it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 125.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 93.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.62it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.06it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.61it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.90it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 85.78it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.47it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.13it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.82it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.83it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.04it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.45it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.02it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.24it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.86it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.84it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.57it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.63it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.95it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.19it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.32it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.84it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.37it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.34it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.92it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.75it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 84.78it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.82it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.55it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.41it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.59it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 123.60it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.22it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.31it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 128.96it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.58it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 86.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.35it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.64it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.14it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.28it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.91it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.93it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.76it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.36it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.79it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.25it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.71it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.10it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.05it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.28it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.29it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.65it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.72it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.42it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.23it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 84.39it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.53it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 122.27it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.88it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 131.17it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.72it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 126.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.69it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.40it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.27it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.56it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.70it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.00it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.33it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.49it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.03it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.08it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 136.52it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.18it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.99it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.15it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.38it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.44it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 130.98it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.73it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.74it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.21it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.87it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 88.01it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.20it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 135.26it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.16it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 134.77it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 132.11it/s]
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 133.11it/s]
# At iterate    2    f=  2.68200D+00    |proj g|=  3.00000D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    88      2     27     89     0     0   3.000D-01   2.682D+00
#   F =   2.6819996886744537
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# Initialize BGM model with calibrated parameters
bgm_mc = BGMMonteCarlo(filtered_maturities, opt_forwards, opt_vols, corr_matrix)

# Simulate paths for pricing
print("\nSimulating forward rate paths...")
dt = filtered_maturities[-1] / 30
paths = bgm_mc.simulate_forward_rates(1000, 30, dt)
# Out:
# Simulating forward rate paths...
# Simulating paths: 100%|██████████| 30/30 [00:00<00:00, 79.53it/s]

# %%
# Load Bond data
csv_file_path = "/Users/dr/Documents/GitHub/FixedIncome/bond data for pricing analysis.csv"  
bond_df = pd.read_csv(csv_file_path)

# Filter and retain only the necessary columns
bond_data = bond_df[['Security', 'Maturity', 'Coupon Rate', 'Price', 'Coupon Frequency']].copy()

# Safely modify the 'Coupon Rate' column
bond_data.loc[:, 'Coupon Rate'] = bond_data['Coupon Rate'] / 100

# Display the updated DataFrame
print(bond_data)
# Out:
#               Security  Maturity  Coupon Rate       Price  Coupon Frequency
# 0          3-mo T-bill      0.25      0.00000    4.192500                 1
# 1   10yr Treasury Bond      9.88      0.04625  104.750000                 2
# 2    5yr Treasury Bond      4.99      0.04000  101.167969                 2
# 3    2yr Treasury Bond      2.66      0.00625   92.320312                 2
# 4             2yr TIPS      3.54      0.02375  104.843750                 2
# 5    Corporate Bond(A)      7.12      0.05125  101.677000                 2
# 6    Corporate Bond(B)      4.66      0.08875   62.076000                 2
# 7  Corporate Bond(BBB)     10.00      0.05500  100.433000                 2

# %%
def compute_bond_prices_with_coupons(model, maturities, face_value=100, coupon_rate=0.0, frequency=2):
    """
    Compute bond prices using a term structure model, including optional coupon payments.
    
    Parameters:
    - model: Object with a `zero(t0, T)` method (e.g., BGM model instance)
    - maturities: Array of times to maturity (in years)
    - face_value: Bond face value (default: 100)
    - coupon_rate: Annual coupon rate as a decimal (default: 0.0)
    - frequency: Number of coupon payments per year (default: 2, semi-annual)
    
    Returns:
    - np.array of bond prices
    """
    prices = np.zeros(len(maturities))  # Pre-allocate array for efficiency
    
    for i, tau in enumerate(maturities):
        # Principal price at maturity
        principal_price = model.zero(0, tau) * face_value
        
        # Coupon price (if applicable)
        if coupon_rate > 0 and tau >= 1 / frequency:
            coupon_payment = (coupon_rate / frequency) * face_value
            num_coupons = int(tau * frequency)
            coupon_times = np.linspace(1 / frequency, tau, num_coupons)
            # Vectorized discount factor calculation
            discounts = np.array([model.zero(0, t) for t in coupon_times])
            coupon_price = np.sum(discounts * coupon_payment)
        else:
            coupon_price = 0
        
        prices[i] = coupon_price + principal_price
    
    return prices

# %%
# STRIPS (zero-coupon) prices
zero_coupon_prices = compute_bond_prices_with_coupons(bgm_mc, maturities, face_value, 0.0, 2)

# Bond prices across STRIPS maturities
bond_model_prices = {}
for _, row in bond_data.iterrows():
    security = row['Security']
    coupon_rate = row['Coupon Rate']
    frequency = row['Coupon Frequency']
    bond_model_prices[security] = compute_bond_prices_with_coupons(bgm_mc, maturities, face_value, coupon_rate, frequency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 # STRIPS (zero-coupon) prices
# ----> 2 zero_coupon_prices = compute_bond_prices_with_coupons(bgm.mc, maturities, face_value, 0.0, 2)
#       4 # Bond prices across STRIPS maturities\n",
#       5 bond_model_prices = {}
#
# NameError: name 'bgm' is not defined

# %%
plt.figure(figsize=(14, 8))
# STRIPS: Model vs Market
plt.plot(maturities, zero_coupon_prices, 'b-', label='STRIPS Model Price', linewidth=1.5)
plt.plot(maturities, prices, 'b--', label='STRIPS Market Price', linewidth=1.5)

plt.xlabel('Maturity (Years)')
plt.ylabel('Price ($)')
plt.title('BGM Model Prices vs Market Prices')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
